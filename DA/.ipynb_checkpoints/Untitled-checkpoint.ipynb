# %%
name="om makwan"
print(name)
# Out:
# om makwan

# %%
a=10
b=20
c=a+b
print("additions of two numbers is :",c)
# Out:
# additions of two numbers is : 30

# %%
# exp=10+30-5*20-25+30-2*12
# print("Output is :",exp)

exp=10+20/10-2
print("Out is :",exp)
# Out:
# Output is : -79
